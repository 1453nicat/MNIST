# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np


mnist  = tf.keras.datasets.mnist
(train_im, train_lab), (test_im, test_lab) = mnist.load_data()

train_im, test_im = train_im / 255.0, test_im / 255.0

# print(f"Train shape: {train_im.shape}")
# print(f"Test shaoe: {test_im.shape}")

model = models.Sequential()
model.add(layers.Flatten(input_shape=(28, 28)))
model.add(layers.Dense(128, activation = 'relu'))
model.add(layers.Dense(10, activation = 'softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# hist = model.fit(train_im, train_lab, epochs=5, validation_split = 0.2)

test_loss, test_acc = model.evaluate(test_im, test_lab)
print("Test accuracy: ", test_acc)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8672 - loss: 0.4699 - val_accuracy: 0.9521 - val_loss: 0.1629
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9591 - loss: 0.1390 - val_accuracy: 0.9672 - val_loss: 0.1137
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9755 - loss: 0.0846 - val_accuracy: 0.9695 - val_loss: 0.1024
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9817 - loss: 0.0600 - val_accuracy: 0.9728 - val_loss: 0.0957
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9866 - loss: 0.0468 - val_accuracy: 0.9737 - val_loss: 0.0914
# ...

# %%
plt.figure(figsize = (15, 5))
im = 12

for i in range(im):
  plt.subplot(1, im, i + 1)
  plt.imshow(test_im[i], cmap = plt.cm.binary)
  plt.title(f"Pred.: {np.argmax(pred[i])} \n True: {test_lab[i]}")
  plt.axis("off")
plt.show()
